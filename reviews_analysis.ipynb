# %%
import pandas as pd
import numpy as np

# %%
reviews = pd.read_csv('data/BaSalam.reviews.csv', low_memory=False)

# %%
def outliers_number(data: pd.Series, iqr=True,  modified=False, threshold=3, threshold_modified=4.5):
    if iqr:
        q1 = data.quantile(0.25)
        q3 = data.quantile(0.75)
        IQR = q3-q1

        return data[(data > q3+IQR*1.5) | (data < q1-IQR*1.5)].index
    else:
        if modified:
            median = data.median()
            mad = np.median(np.abs(data - median))
            
            modified_z_scores = 0.6745 * (data - median) / mad

            return data[np.abs(modified_z_scores) > threshold_modified].index
        else:
            z_score = (data - data.mean()) / data.std()
            return data[np.abs(data) > threshold].index

# %%
cols = reviews.columns.tolist()

# %%
miss_values = pd.Series([int(reviews[col].isna().sum()) for col in cols])

# %%
def outlier_len(iqr, modified):
    outlier_iqr = []
    for col in cols:
        if (type(reviews[col][0]) in [np.int64, np.float64]):
            outlier_iqr.append(len(outliers_number(reviews[col], iqr, modified)))
        else:
            outlier_iqr.append(np.nan)

    return pd.Series(outlier_iqr)

# %%
pd.DataFrame(index=reviews.columns.tolist(),
             data={
            'miss value': miss_values.values,
            "type": reviews.dtypes.values,
            'outlier_iqr': outlier_len(True, False).values,
            'outlier_Z-score': outlier_len(False, False).values,
            'outlier_Z-score modified': outlier_len(False, True).values,
            'Most repeated': [reviews[col].value_counts().index[0] for col in cols]
            })
# Out:
#                          miss value     type  outlier_iqr  outlier_Z-score  \
# _id                               0   object          NaN              NaN
# productId                         0    int64          0.0        3393574.0
# star                              0    int64     735113.0        3046546.0
# user_id                           0    int64          0.0        3393574.0
# isPost                            0     bool          NaN              NaN
# isPublic                          0     bool          NaN              NaN
# id                                0    int64          0.0        3393574.0
# createdAt                         0   object          NaN              NaN
# updatedAt                         0   object          NaN              NaN
# hashId                            0   object          NaN              NaN
# isPosted                     245741   object          NaN              NaN
# isLikedByCurrentUser              0     bool          NaN              NaN
# isDislikedByCurrentUser           0     bool          NaN              NaN
# likeCount                         0    int64      83281.0          37546.0
# dislikeCount                      0    int64          0.0              0.0
# attachments                       0   object          NaN              NaN
# history_count                     0    int64     141730.0          11918.0
# user_id_of_user                   0    int64          0.0        3321440.0
# name_of_user                      5   object          NaN              NaN
# hash_id_of_user                   0   object          NaN              NaN
# photo_of_user               2660831   object          NaN              NaN
# description                 1391786   object          NaN              NaN
# reason_ids[0]               3152350  float64          0.0         241151.0
# reason_ids[1]               3178940  float64          0.0         214570.0
# reason_ids[2]               3218274  float64          0.0         175251.0
# reason_ids[3]               3262435  float64          0.0         131139.0
# reason_ids[4]               3393314  float64          0.0            260.0
# reason_ids[5]               3393540  float64          1.0             34.0
# reason_ids[6]               3393549  float64          0.0             25.0
# reason_ids[7]               3393554  float64          0.0             20.0
# variation_metadata          3209873   object          NaN              NaN
#
#                          outlier_Z-score modified  \
# _id                                           NaN
# productId                                     0.0
# star                                     735113.0
# user_id                                       0.0
# isPost                                        NaN
# isPublic                                      NaN
# id                                            0.0
# createdAt                                     NaN
# updatedAt                                     NaN
# hashId                                        NaN
# isPosted                                      NaN
# isLikedByCurrentUser                          NaN
# isDislikedByCurrentUser                       NaN
# likeCount                                862745.0
# dislikeCount                                  0.0
# attachments                                   NaN
# history_count                            141730.0
# user_id_of_user                               0.0
# name_of_user                                  NaN
# hash_id_of_user                               NaN
# photo_of_user                                 NaN
# description                                   NaN
# reason_ids[0]                                 0.0
# reason_ids[1]                                 0.0
# reason_ids[2]                                 0.0
# reason_ids[3]                                 0.0
# reason_ids[4]                                 0.0
# reason_ids[5]                                 0.0
# reason_ids[6]                                 0.0
# reason_ids[7]                                 0.0
# variation_metadata                            NaN
#
#                                                              Most repeated
# _id                                               661bad526a6e1c5d7e98fd66
# productId                                                          2810984
# star                                                                     5
# user_id                                                             980257
# isPost                                                               False
# isPublic                                                              True
# id                                                                 8294857
# createdAt                                              2021-01-27T11:04:34
# updatedAt                                              2021-01-27T11:04:34
# hashId                                                            Infinity
# isPosted                                                             False
# isLikedByCurrentUser                                                 False
# isDislikedByCurrentUser                                              False
# likeCount                                                                0
# dislikeCount                                                             0
# attachments                                  {'photos': [], 'video': None}
# history_count                                                            1
# user_id_of_user                                                          0
# name_of_user                                                  دوست باسلامی
# hash_id_of_user                                                         aN
# photo_of_user            {'LARGE': '', 'MEDIUM': '', 'SMALL': '', 'EXTR...
# description                                                           عالی
# reason_ids[0]                                                        153.0
# reason_ids[1]                                                        154.0
# reason_ids[2]                                                        155.0
# reason_ids[3]                                                        156.0
# reason_ids[4]                                                        160.0
# reason_ids[5]                                                         94.0
# reason_ids[6]                                                        368.0
# reason_ids[7]                                                         96.0
# variation_metadata       [{'id': 155479324, 'properties': [{'value': {'...

# %%
drop_cols = [
    'user_id_of_user', 'hashId', 'hash_id_of_user', 'reason_ids[0]',
    'reason_ids[1]', 'reason_ids[2]', 'reason_ids[3]', 'reason_ids[4]',
    'reason_ids[5]', 'reason_ids[6]', 'reason_ids[7]', 'variation_metadata'
]

# %%
data = reviews.drop(columns=drop_cols)

# %%
reviews['createdAt'] = pd.to_datetime(reviews['createdAt'])
sells_by_date = reviews['createdAt'].dt.date.value_counts().sort_index()
sells_by_date = pd.DataFrame({
    'day': pd.to_datetime(sells_by_date.index),
    'amount': sells_by_date.values
})
sells_by_date
# Out:
#             day  amount
# 0    2018-09-22       1
# 1    2018-09-23       4
# 2    2018-09-24       5
# 3    2018-09-25      11
# 4    2018-09-26       3
# ...         ...     ...
# 1978 2024-04-05    2739
# 1979 2024-04-06    3266
# 1980 2024-04-07    1601
# 1981 2024-04-08    1028
# 1982 2024-04-09     117
#
# [1983 rows x 2 columns]
