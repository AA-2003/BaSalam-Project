# %%
import pandas as pd
import numpy as np

# import dtale

# %%
products = pd.read_csv('data/BaSalam.products.csv', low_memory=False)

# %%
# d = dtale.show(products)
# d.open_browser()

# %%
def outliers_number(data: pd.Series, iqr=True,  modified=False, threshold=3, threshold_modified=4.5):
    if iqr:
        q1 = data.quantile(0.25)
        q3 = data.quantile(0.75)
        IQR = q3-q1

        return data[(data > q3+IQR*1.5) | (data < q1-IQR*1.5)].index
    else:
        if modified:
            median = data.median()
            mad = np.median(np.abs(data - median))
            
            modified_z_scores = 0.6745 * (data - median) / mad

            return data[np.abs(modified_z_scores) > threshold_modified].index
        else:
            z_score = (data - data.mean()) / data.std()
            return data[np.abs(data) > threshold].index

# %%
cols = products.columns.tolist()

# %%
miss_values = pd.Series([int(products[col].isna().sum()) for col in cols])

# %%
def outlier_len(iqr, modified):
    outlier_iqr = []
    for col in cols:
        if (type(products[col][0]) in [np.int64, np.float64]):
            outlier_iqr.append(len(outliers_number(products[col], iqr, modified)))
        else:
            outlier_iqr.append(np.nan)

    return pd.Series(outlier_iqr)

# %%
pd.DataFrame(index=products.columns.tolist(),
             data={
            'miss value': miss_values.values,
            "type": products.dtypes.values,
            'outlier_iqr': outlier_len(True, False).values,
            'outlier_Z-score': outlier_len(False, False).values,
            'outlier_Z-score modified': outlier_len(False, True).values,
            'Most repeated': [products[col].value_counts().index[0] for col in cols]
            })
# Out:
#                                miss value     type  outlier_iqr  \
# _id                                     0    int64          0.0
# _score                                  0  float64      76942.0
# sales_count_week                        0    int64      76942.0
# name                                    8   object          NaN
# price                                   2  float64     329395.0
# status_id                               2  float64       2583.0
# status_title                         2585   object          NaN
# stock                                   2  float64     419092.0
# photo_MEDIUM                          540   object          NaN
# photo_SMALL                           540   object          NaN
# rating_average                          3  float64          0.0
# rating_count                            3  float64     297856.0
# rating_signals                          3  float64     297856.0
# primaryPrice                            3  float64     301409.0
# preparationDays                         3  float64     204105.0
# weight                                  3  float64     321858.0
# categoryId                         146163  float64     297810.0
# has_delivery                       146166   object          NaN
# has_variation                           3   object          NaN
# new_categoryId                          3  float64      42054.0
# navigation_id                     2363132  float64       3054.0
# vendor_name                             3   object          NaN
# vendor_identifier                       3   object          NaN
# vendor_statusId                         3  float64        907.0
# vendor_freeShippingToIran          669330  float64     200545.0
# vendor_freeShippingToSameCity      786896  float64     121384.0
# vendor_cityId                           3  float64          0.0
# vendor_provinceId                       3  float64          0.0
# vendor_has_delivery                 10409   object          NaN
# vendor_score                      1239540  float64          0.0
# vendor_id                               3  float64          0.0
# vendor_status_id                        3  float64        907.0
# vendor_status_title                     3   object          NaN
# vendor_owner_city                       7   object          NaN
# vendor_owner_id                         3  float64          0.0
# isFreeShipping                          3   object          NaN
# IsAvailable                             3   object          NaN
# IsSaleable                              3   object          NaN
# mainAttribute                     2213550   object          NaN
# categoryTitle                          46   object          NaN
# published                         2341306   object          NaN
# video_ORIGINAL                    2254969   object          NaN
# promotions                        2411289   object          NaN
#
#                                outlier_Z-score  outlier_Z-score modified  \
# _id                                  2411358.0                       0.0
# _score                               1024592.0                 1024592.0
# sales_count_week                        2703.0                   76942.0
# name                                       NaN                       NaN
# price                                2411356.0                       0.0
# status_id                            2411356.0                       0.0
# status_title                               NaN                       NaN
# stock                                1558952.0                       0.0
# photo_MEDIUM                               NaN                       NaN
# photo_SMALL                                NaN                       NaN
# rating_average                        727152.0                       0.0
# rating_count                          224061.0                       0.0
# rating_signals                        224061.0                       0.0
# primaryPrice                         1450081.0                       0.0
# preparationDays                       644132.0                       0.0
# weight                               2368259.0                       0.0
# categoryId                            297810.0                       0.0
# has_delivery                               NaN                       NaN
# has_variation                              NaN                       NaN
# new_categoryId                       2411355.0                       0.0
# navigation_id                          34884.0                       0.0
# vendor_name                                NaN                       NaN
# vendor_identifier                          NaN                       NaN
# vendor_statusId                      2411355.0                       0.0
# vendor_freeShippingToIran            1615749.0                       0.0
# vendor_freeShippingToSameCity        1475651.0                       0.0
# vendor_cityId                        2411355.0                       0.0
# vendor_provinceId                    2308698.0                       0.0
# vendor_has_delivery                        NaN                       NaN
# vendor_score                               0.0                       0.0
# vendor_id                            2411355.0                       0.0
# vendor_status_id                     2411355.0                       0.0
# vendor_status_title                        NaN                       NaN
# vendor_owner_city                          NaN                       NaN
# vendor_owner_id                      2411355.0                       0.0
# isFreeShipping                             NaN                       NaN
# IsAvailable                                NaN                       NaN
# IsSaleable                                 NaN                       NaN
# mainAttribute                              NaN                       NaN
# categoryTitle                              NaN                       NaN
# published                                  NaN                       NaN
# video_ORIGINAL                             NaN                       NaN
# promotions                                 NaN                       NaN
#
#                                                                    Most repeated
# _id                                                                     13189182
# _score                                                                       0.0
# sales_count_week                                                               0
# name                                                                     هفت سین
# price                                                                  1500000.0
# status_id                                                                 2976.0
# status_title                                                            در دسترس
# stock                                                                        1.0
# photo_MEDIUM                   https://statics.basalam.com/public/users/xn5O8...
# photo_SMALL                    https://statics.basalam.com/public/users/xn5O8...
# rating_average                                                               0.0
# rating_count                                                                 0.0
# rating_signals                                                               0.0
# primaryPrice                                                                 0.0
# preparationDays                                                              1.0
# weight                                                                     100.0
# categoryId                                                                   0.0
# has_delivery                                                                True
# has_variation                                                              False
# new_categoryId                                                             790.0
# navigation_id                                                                1.0
# vendor_name                     تاپیکس TOPX | تحویل سفارش از 7 نوروز به بعد است.
# vendor_identifier                                                          top_x
# vendor_statusId                                                           2987.0
# vendor_freeShippingToIran                                             10000000.0
# vendor_freeShippingToSameCity                                          5000000.0
# vendor_cityId                                                             2052.0
# vendor_provinceId                                                           10.0
# vendor_has_delivery                                                         True
# vendor_score                                                                 0.0
# vendor_id                                                               873468.0
# vendor_status_id                                                          2987.0
# vendor_status_title                                                         فعال
# vendor_owner_city                                                          تهران
# vendor_owner_id                                                        3270373.0
# isFreeShipping                                                             False
# IsAvailable                                                                 True
# IsSaleable                                                                  True
# mainAttribute                                                           1000 گرم
# categoryTitle                                                               سایر
# published                                                                   True
# video_ORIGINAL                 https://basalam-com.arvanvod.ir/yOpvGE3e0D/YP0...
# promotions                     {'type': 'FLASH_SALES_NOW', 'link': None, 'tit...

# %%
drop_cols =['video_ORIGINAL', 'status_id',
            'photo_MEDIUM', 'photo_SMALL', 'rating_signals',
            'categoryId','vendor_owner_id', 'vendor_status_id',
            'published', 'promotions', 'mainAttribute',
            'vendor_statusId', 'vendor_cityId', 'vendor_id',
            'new_categoryId', 
            ]
data = products.drop(columns=drop_cols)

# %%
data[data['_id']==1948970]
# Out:
#             _id     _score  sales_count_week  \
# 132592  1948970  444.44446                 7
#
#                                                      name      price  \
# 132592  خرما خاصویی3کیلویی  درجه یک محصول 1402با تخفیف...  2050000.0
#
#        status_title  stock  rating_average  rating_count  primaryPrice  ...  \
# 132592     در دسترس   35.0             4.6        1333.0     2400000.0  ...
#
#         vendor_freeShippingToSameCity  vendor_provinceId vendor_has_delivery  \
# 132592                            NaN               19.0                True
#
#        vendor_score  vendor_status_title vendor_owner_city isFreeShipping  \
# 132592          1.0                 فعال               قیر          False
#
#         IsAvailable  IsSaleable  categoryTitle
# 132592         True        True           خرما
#
# [1 rows x 28 columns]

# %%
x = list(data['categoryId'].value_counts().index)
map_ = {}
for i,j in enumerate(x):
    map_[j] = i
categrory_normald = data.copy()
categrory_normald['categoryId'] = categrory_normald['categoryId'].map(map_)

# %%
sales_by_catrgory = categrory_normald[categrory_normald['sales_count_week']!=0].groupby('categoryId')['sales_count_week'].mean()
sales_by_catrgory= pd.DataFrame({'category': sales_by_catrgory.index,
              'values': sales_by_catrgory.values})

# %%
sales_by_catrgory.sort_values(by='values', ascending=False)[0:10]
# Out:
#      category    values
# 184     185.0  3.636364
# 226     229.0  2.800000
# 264     275.0  2.800000
# 185     186.0  2.500000
# 251     260.0  2.500000
# 165     166.0  2.444444
# 13       13.0  2.145530
# 124     125.0  2.090909
# 28       28.0  2.009901
# 254     263.0  2.000000

# %%
x = data.sort_values(by='price', ascending=False).iloc[:1000][['name', 'price']]
x[x['price'] < 899999990.0]
# Out:
#                                                       name        price
# 196694                   برنج طارم هاشمی درجه 1 عمده(2تنی)  899990000.0
# 1356721                         یخچال ساید بای ساید ال جی   899000000.0
# 863899                        فرش دستباف جفت 9 متری خطیبی   899000000.0
# 1356770  یخچال فریزر 36 فوت ساید بای ساید دوو مدل 3640M...  898940000.0
# 1339993           چرخ خیاطی 7-8 فرش دوز تیپیکال مدل TW7-6B  898500000.0
# ...                                                    ...          ...
# 1069516  یخچال فریزر دوقلو 40 فوت دوو مدل 2030ss رنگ نق...  689860000.0
# 1083575  وان و جکوزی ترمو جکوزی دونفره با متعلقات طلایی...  689000000.0
# 891578   سرویس خواب دونفره نئوکلاسیک سوفیا (ارسال با با...  689000000.0
# 1356934  یخچال فریزر ساید بای ساید کندی SBS-SCR 34 S سی...  689000000.0
# 2215502           باند پسیو الکتروویس ELECTRO VOICE TX1152  689000000.0
#
# [653 rows x 2 columns]

# %%
filtered = data[data['categoryTitle'] != 'سایر'].groupby('categoryTitle')[['rating_average', 'categoryTitle']].filter(lambda x : len(x) > 9000)
avg_category_rate = filtered.groupby('categoryTitle')['rating_average'].mean()

# %%
avg_category_rate.sort_values(ascending=False)
# Out:
# categoryTitle
# کتاب چاپی                        4.272205
# ادویه                            4.264962
# عطر و ادکلن زنانه و مردانه       3.820212
# ظروف سرو و پذیرایی               3.785402
# لوازم پخت و پز                   3.760190
# گیاهان دارویی                    3.562719
# ظروف آشپزخانه                    3.427734
# داروهای گیاهی                    3.215669
# گیاهان آپارتمانی                 2.476343
# لوازم خیاطی                      2.424854
# بذر و تخم گیاهان                 2.417628
# ابزار قنادی                      2.246346
# فلاسک، کلمن و ماگ                2.107724
# لوازم تهیه و سرو چای             1.911071
# قاشق، چنگال و کارد               1.799050
# لامپ، چراغ و مهتابی              1.756268
# خاک، کود و آفت کش                1.652326
# سایر لوازم یدکی موتورسیکلت       1.575788
# روتختی و پتو                     1.529460
# محصولات بافتنی                   1.520882
# لوازم دستشویی                    1.420168
# پارچ، لیوان و بطری               1.417661
# سطل، سبد و آبکش                  1.403513
# سنگ های قیمتی                    1.318892
# لوازم حمام                       1.251643
# سرویس پارچه ای آشپزخانه          1.202246
# گلدان                            0.986258
# چای ساز و قهوه ساز               0.963652
# میز                              0.936245
# خردکن و غذاساز                   0.787002
# جاروبرقی، جاروشارژی و بخارشوی    0.752358
# ظروف سفالی                       0.698563
# کیف چرم دست دوز                  0.648382
# دکوراتیو سفالی و سرامیکی         0.632422
# فرش ماشینی                       0.500062
# مبل                              0.448488
# Name: rating_average, dtype: float64

# %%
data[data['categoryTitle'] != 'سایر'
        ].groupby('categoryTitle')[[ 'categoryTitle', 'rating_count']
        ].filter(lambda x : len(x) > 9000 and sum(x['rating_count'])> 1000
        ).groupby('categoryTitle')['rating_count'].mean(            
        ).sort_values(ascending=False)
# Out:
# categoryTitle
# ادویه                            14.672708
# کتاب چاپی                         8.770501
# داروهای گیاهی                     5.626436
# عطر و ادکلن زنانه و مردانه        5.042523
# گیاهان دارویی                     4.709359
# لوازم پخت و پز                    4.133074
# ظروف سرو و پذیرایی                3.224931
# ظروف آشپزخانه                     3.016614
# بذر و تخم گیاهان                  2.678167
# گیاهان آپارتمانی                  2.235639
# لامپ، چراغ و مهتابی               2.040504
# لوازم خیاطی                       1.841032
# فلاسک، کلمن و ماگ                 1.616573
# ابزار قنادی                       1.577346
# قاشق، چنگال و کارد                1.551129
# لوازم تهیه و سرو چای              1.482495
# لوازم حمام                        1.410002
# سطل، سبد و آبکش                   1.337179
# خاک، کود و آفت کش                 1.244906
# پارچ، لیوان و بطری                1.232898
# روتختی و پتو                      1.196123
# چای ساز و قهوه ساز                1.105083
# لوازم دستشویی                     1.090439
# سنگ های قیمتی                     1.007652
# گلدان                             0.942960
# سایر لوازم یدکی موتورسیکلت        0.942400
# میز                               0.869606
# محصولات بافتنی                    0.735649
# سرویس پارچه ای آشپزخانه           0.727029
# خردکن و غذاساز                    0.664992
# کیف چرم دست دوز                   0.578513
# جاروبرقی، جاروشارژی و بخارشوی     0.491275
# ظروف سفالی                        0.418905
# مبل                               0.288689
# دکوراتیو سفالی و سرامیکی          0.256123
# فرش ماشینی                        0.191996
# Name: rating_count, dtype: float64
